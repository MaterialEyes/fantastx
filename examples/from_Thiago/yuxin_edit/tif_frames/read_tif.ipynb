# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image
# Out:
# Jupyter cannot be started. Error attempting to locate Jupyter: Running cells with '/usr/bin/python3' requires the notebook and jupyter package.
#
# Run the following command to install 'jupyter and notebook' into the Python environment.
#
# Command: 'python -m pip install jupyter notebook -U
#
# or
#
# conda install jupyter notebook -U'
#
# Click <a href='https://aka.ms/installJupyterForVSCode'>here</a> for more info.

# %%
# Load the TIFF image
image = cv2.imread('frame 1.tif', cv2.IMREAD_UNCHANGED)

# Display the image
plt.imshow(image, cmap='gray')
plt.axis('off')  # Turn off axis
plt.show()

# %%
# Load the TIFF image
# image = cv2.imread('frame 1.tif', cv2.IMREAD_UNCHANGED)
image = cv2.imread('020210721JLV_PtCeO2_030303_2116pm2_binx2_Fr 471-501_UDVDMF denoised.tif', cv2.IMREAD_UNCHANGED)
# image = cv2.imread('020210721JLV_PtCeO2_030303_2116pm2_binx2_Fr 471-501_rawdata.tif', cv2.IMREAD_UNCHANGED)
# Display the image
plt.imshow(image, cmap='gray')
plt.axis('off')  # Turn off axis
plt.show()

# %%
# Open the TIFF image
image = Image.open('020210721JLV_PtCeO2_030303_2116pm2_binx2_Fr 471-501_UDVDMF denoised.tif')
# image = Image.open('020210721JLV_PtCeO2_030303_2116pm2_binx2_Fr 471-501_rawdata.tif')
# Convert the TIFF image to grayscale
grayscale_image = image.convert('L')
# Convert the TIFF image to GIF format
image.save('output_image.gif', format='GIF', save_all=True, duration=200, loop=0)

# %%
image = cv2.imread('020210721JLV_PtCeO2_030303_2116pm2_binx2_Fr 471-501_UDVDMF denoised.tif')
pil_image = Image.fromarray(image)

# Save the image as a GIF using PIL
pil_image.save('output_image.gif', format='GIF', save_all=True, duration=100, loop=0)
# Out:
# [ WARN:0@3093.328] global grfmt_tiff.cpp:714 readData OpenCV TIFF: TIFFRGBAImageOK: Sorry, can not handle images with 32-bit samples
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 image = cv2.imread('020210721JLV_PtCeO2_030303_2116pm2_binx2_Fr 471-501_UDVDMF denoised.tif')
# ----> 2 pil_image = Image.fromarray(image)
#       4 # Save the image as a GIF using PIL
#       5 pil_image.save('output_image.gif', format='GIF', save_all=True, duration=100, loop=0)
#
# File ~/.local/lib/python3.9/site-packages/PIL/Image.py:3087, in fromarray(obj, mode)
#    3040 def fromarray(obj, mode=None):
#    3041     """
#    3042     Creates an image memory from an object exporting the array interface
#    3043     (using the buffer protocol)::
#    (...)
#    3085     .. versionadded:: 1.1.6
#    3086     """
# -> 3087     arr = obj.__array_interface__
# ...
