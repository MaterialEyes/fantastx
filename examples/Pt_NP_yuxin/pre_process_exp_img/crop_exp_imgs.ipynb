# %%
import cv2
import matplotlib.pyplot as plt

# %%
exp_img.shape[0]
# Out:
# 230

# %%
exp_img = cv2.imread('./images_from_tif/denoised_13.png', cv2.IMREAD_GRAYSCALE)
plt.imshow(exp_img,cmap='gray')
exp_img.shape
# Out:
# (230, 330)

# %%
for i in range(1,32):
    exp_img = cv2.imread(f'./images_from_tif/denoised_{i}.png', cv2.IMREAD_GRAYSCALE)
    cropped_exp_image = exp_img[30:30+135, 65:65+180]
    # plt.imshow(cropped_exp_image,cmap='gray')
    cv2.imwrite(f'./images_from_tif_cropped/denoised_{i}.png', cropped_exp_image)

# %%
cropped_exp_image = exp_img[30:30+135, 65:65+180]

# %%
plt.imshow(cropped_exp_image,cmap='gray')

# %%
cv2.imwrite('cropped_image.jpg', cropped_exp_image)
cv2.imshow('Cropped Image', cropped_exp_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 cv2.imwrite('cropped_image.jpg', cropped_exp_image)
#       2 cv2.imshow('Cropped Image', cropped_exp_image)
#
# NameError: name 'cropped_exp_image' is not defined

# %%
aa = cv2.imread('./images_from_tif/denoised_13.png', cv2.IMREAD_GRAYSCALE)
aa
# Out:
# array([[119, 120, 114, ..., 120, 121, 112],
#        [120, 117, 115, ..., 121, 116, 112],
#        [116, 116, 116, ..., 121, 119, 122],
#        ...,
#        [ 96,  94,  91, ...,  22,  23,  23],
#        [ 98,  96, 100, ...,   8,  10,  10],
#        [ 99, 105, 109, ...,   7,   8,   9]], dtype=uint8)

# %%
cv2.imwrite('aa.png',aa)
# Out:
# True

# %%
cv2.imread('aa.png', cv2.IMREAD_GRAYSCALE)
# Out:
# array([[119, 120, 114, ..., 120, 121, 112],
#        [120, 117, 115, ..., 121, 116, 112],
#        [116, 116, 116, ..., 121, 119, 122],
#        ...,
#        [ 96,  94,  91, ...,  22,  23,  23],
#        [ 98,  96, 100, ...,   8,  10,  10],
#        [ 99, 105, 109, ...,   7,   8,   9]], dtype=uint8)

# %%
cv2.imread(f'/home/yuxin.chang/fantastx/examples/Pt_NP_yuxin/pre_process_exp_img/images_from_tif_cropped/denoised_13.png', cv2.IMREAD_GRAYSCALE)
# Out:
# array([[120, 118, 117, ..., 119, 116, 122],
#        [116, 115, 115, ..., 123, 123, 123],
#        [119, 114, 117, ..., 126, 128, 128],
#        ...,
#        [117, 114, 112, ...,  31,  28,  25],
#        [123, 120, 107, ...,  18,  17,  16],
#        [121, 117, 110, ...,  23,  22,  22]], dtype=uint8)

# %%
plt.imshow(cropped_exp_image)

# %%
flipped = cv2.flip(cropped_exp_image, 0)
plt.imshow(flipped,cmap='gray')

# %%
flipped.shape
# Out:
# (135, 180)

# %%
plt.imshow(flipped)
plt.savefig('flipped.png',bbox_inches='tight', pad_inches=0)  # Save the figure as a PNG

# %%
plt.savefig?
# Out:
# Signature: plt.savefig(*args, **kwargs) -> 'None'
# Docstring:
# Save the current figure.
#
# Call signature::
#
#   savefig(fname, *, transparent=None, dpi='figure', format=None,
#           metadata=None, bbox_inches=None, pad_inches=0.1,
#           facecolor='auto', edgecolor='auto', backend=None,
#           **kwargs
#          )
#
# The available output formats depend on the backend being used.
#
# Parameters
# ----------
# fname : str or path-like or binary file-like
#     A path, or a Python file-like object, or
#     possibly some backend-dependent object such as
#     `matplotlib.backends.backend_pdf.PdfPages`.
#
#     If *format* is set, it determines the output format, and the file
#     is saved as *fname*.  Note that *fname* is used verbatim, and there
#     is no attempt to make the extension, if any, of *fname* match
#     *format*, and no extension is appended.
#
#     If *format* is not set, then the format is inferred from the
# ...

# %%
cv2.imwrite('fliped.png',flipped[,cv2.IMREAD_GRAYSCALE])
# Out:
#   Cell In[61], line 1
#     cv2.imwrite('fliped.png',flipped[,cv2.IMREAD_GRAYSCALE])
#                                      ^
# SyntaxError: invalid syntax

# %%
cv2.imwrite?
# Out:
# Docstring:
# imwrite(filename, img[, params]) -> retval
# .   @brief Saves an image to a specified file.
# .
# .   The function imwrite saves the image to the specified file. The image format is chosen based on the
# .   filename extension (see cv::imread for the list of extensions). In general, only 8-bit unsigned (CV_8U)
# .   single-channel or 3-channel (with 'BGR' channel order) images
# .   can be saved using this function, with these exceptions:
# .
# .   - With OpenEXR encoder, only 32-bit float (CV_32F) images can be saved.
# .     - 8-bit unsigned (CV_8U) images are not supported.
# .   - With Radiance HDR encoder, non 64-bit float (CV_64F) images can be saved.
# .     - All images will be converted to 32-bit float (CV_32F).
# .   - With JPEG 2000 encoder, 8-bit unsigned (CV_8U) and 16-bit unsigned (CV_16U) images can be saved.
# .   - With PAM encoder, 8-bit unsigned (CV_8U) and 16-bit unsigned (CV_16U) images can be saved.
# ...

# %%
plt.savefig?
# Out:
# Signature: plt.savefig(*args, **kwargs) -> 'None'
# Docstring:
# Save the current figure.
#
# Call signature::
#
#   savefig(fname, *, transparent=None, dpi='figure', format=None,
#           metadata=None, bbox_inches=None, pad_inches=0.1,
#           facecolor='auto', edgecolor='auto', backend=None,
#           **kwargs
#          )
#
# The available output formats depend on the backend being used.
#
# Parameters
# ----------
# fname : str or path-like or binary file-like
#     A path, or a Python file-like object, or
#     possibly some backend-dependent object such as
#     `matplotlib.backends.backend_pdf.PdfPages`.
#
#     If *format* is set, it determines the output format, and the file
#     is saved as *fname*.  Note that *fname* is used verbatim, and there
#     is no attempt to make the extension, if any, of *fname* match
#     *format*, and no extension is appended.
#
#     If *format* is not set, then the format is inferred from the
# ...

# %%
cv2.imread(img_file_path, cv2.IMREAD_GRAYSCALE)
